# %% [markdown]
# # Imports

# %%
import time
import shutil
import os
import tarfile
import stat
import multiprocessing as mp
import subprocess
import sys

# %% [markdown]
# # Functions

# %%
def fetch_project_df(profID):
  '''Wrapper to API at www.ebi.ac.uk/ena'''
  import requests
  import json
  import pandas

  url = 'https://www.ebi.ac.uk/ena/portal/api/filereport'
  params = {'accession':profID,
            'format':'json',
            'download':'false',
            'result':'read_run'}
  headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"+
             " AppleWebKit/537.36 (KHTML, like Gecko)"+
             " Chrome/70.0.3538.77 Safari/537.36"}

  print("Accessing: ", url)
  r = requests.get(url,
                  params = params,
                  headers = headers
                  ) 
  print("\tMaking Request To: ", r.url) 
  my_json = json.loads(r.text)
  df = pandas.json_normalize(json.loads(r.text))
  return df

# %%
def build_hisat2(histast_url):
  import time
  import shutil
  import os
  import tarfile
  import stat

  installed_wget = True
  try:
    import wget
  except ModuleNotFoundError:
    installed_wget = False
    import subprocess

  
  print("Downloading HISAT2 at: ", histast_url)
  if installed_wget: 
    wget.download(histast_url)
  else:
    subprocess.run(["wget", histast_url])

  print("Inflating HISAT2 at: ", os.getcwd())
  shutil.unpack_archive(histast_url.split("/")[-1], os.getcwd(),"zip")
  
  #for root, dirs, files in os.walk(os.path.join(os.getcwd(),
  #          histast_url.split("/")[-1].replace("-Linux_x86_64.zip",""))):
  #  for d in dirs:
  #    os.chmod(os.path.join(root, d), stat.S_IEXEC) #owner execute
  #  for f in files:
  #    os.chmod(os.path.join(root, f), stat.S_IEXEC) #owner execute

  hisatpath = os.path.join(os.getcwd(),
            histast_url.split("/")[-1].replace("-Linux_x86_64.zip",""),
             "hisat2")
  return hisatpath

def download_indexes(index_url):
  import time
  import shutil
  import os
  import tarfile
  import stat

  installed_wget = True
  try:
    import wget
  except ModuleNotFoundError:
    installed_wget = False
    import subprocess

  print("Downloading INDEXES at: ", index_url)
  if installed_wget: 
    wget.download(index_url)
  else:
    subprocess.run(["wget", index_url])

  print("Inflating Indexes at: ", os.getcwd())
  file = tarfile.open(index_url.split("/")[-1])
  file.extractall('{}/{}'.format(os.getcwd(),
                                 index_url.split("/")[-1].replace(".tar.gz","")))

  indexpath = os.path.join(os.getcwd(),
            index_url.split("/")[-1].replace(".tar.gz",""))
  return indexpath

# %% [markdown]
# # Install and Build hisat and index

# %%
my_local_path = "/gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/"
datapath = "/gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data"

# %% [markdown]
# # Main

# %% [markdown]
# ## Setup

# %%
# Path to HISAT2 executable
HISAT2_path = ''.join([my_local_path,"hisat2-2.2.1/hisat2"])

# Path to reference genomes
index_path = ''.join([my_local_path,"grch38_genome"])

print("HISAT2 Path: {}".format(HISAT2_path))
print("Indexes Path: {}".format(index_path))
# Out:
# HISAT2 Path: /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/hisat2-2.2.1/hisat2
# Indexes Path: /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/grch38_genome

# %%
if not os.path.exists(HISAT2_path):
    hisat2_url= "https://cloud.biohpc.swmed.edu/index.php/s/oTtGWbWjaxsQ2Ho/download/hisat2-2.2.1-Linux_x86_64.zip"
    HISAT2_path = build_hisat2(hisat2_url)
    
if not os.path.exists(index_path):
    index_url = "https://genome-idx.s3.amazonaws.com/hisat/grch38_genome.tar.gz"
    index_path = download_indexes(index_url)

# %%
# !ls /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data
# Out:
# bam_files  PRJEB35615	PRJNA281708  PRJNA634526
# csv_files  PRJNA277616	PRJNA41223   sam_files

# %%
directories = os.listdir(datapath)
#directories = ["PRJNA475246","PRJEB35615"] # Process Single Project
for directory in directories:
    if not directory.startswith("PRJ"):
        continue
    print("Processing Project: {}".format(directory))
    # Fetch Metadata for Project from ENA API
    df = fetch_project_df(directory)
    project = '/'.join([datapath, directory])
    print("\tProject Path: ",project)
    
    runs = [x.replace(".fastq","").replace("_1","").replace("_2","") for x in sorted(os.listdir(project))]
    runs = list(set(runs))
    single_read = False
    for i in range(len(runs)):
        print()
        run = runs[i]
        #print("\tRun: ", run)
        outfile = "{}.sam".format(run)
        subset = df[df['run_accession']==run]
        if subset.empty: continue
        if ';' in subset['fastq_ftp'].values[0]:
            urls = subset['fastq_ftp'].values[0].split(";")
        else:
            urls = [subset['fastq_ftp'].values[0]]
            single_read = True
        print("\tRun: ",run)
        print("\tSingle Read? :", single_read)
        
        
        # Dont Reprocesses if the .sam file exists 
        if os.path.exists('{}/sam_files/{}/{}'.format(datapath, directory,outfile)):
            print("{} already is processsed. {} Exists. Continuing.".format(run,
                                    '{}/sam_files/{}/{}'.format(datapath, directory,outfile)))
            continue
        if single_read:
            read1 = os.path.join(project, "{}.fastq".format(run))
            if not os.path.exists(read1):
                read1 = os.path.join(project, "{}_1.fastq".format(run))   
            cmd = [HISAT2_path,
           "-p{}".format(mp.cpu_count()),
           "-q",
           "-x",
           "$HISAT2_INDEXES/genome",
           "-U",
           read1,
           "-S",
           outfile,
           "--time"]
        else:
            read1 = os.path.join(project, "{}_1.fastq".format(run))
            read2 = os.path.join(project, "{}_2.fastq".format(run))

            cmd = [HISAT2_path,
           "-p{}".format(mp.cpu_count()),
           "-q",
           "-x",
           "$HISAT2_INDEXES/genome",
           "-1",
           read1,
           "-2",
           read2,
           "-S",
           outfile,
           "--time"]
        print("\tRunning Command: ")
        print(*cmd, sep =" ")
        my_env = {**os.environ,
          'HISAT2_INDEXES': '{}/grch38/'.format(index_path)}

        process = subprocess.Popen(cmd, 
                            stdout=subprocess.PIPE, 
                            stderr=subprocess.STDOUT,
                            env = my_env)
        for line in process.stdout:
            sys.stdout.write(line)
        print()
        print("Moving {} to {}".format(outfile, '{}/sam_files/{}/{}'.format(datapath, directory,outfile)))
        
        if not os.path.exists('{}/sam_files/{}'.format(datapath, directory)):
            os.makedirs('{}/sam_files/{}'.format(datapath, directory))
        shutil.move(outfile, '{}/sam_files/{}/{}'.format(datapath, directory,outfile))
# Out:
# Processing Project: PRJNA281708
# Accessing:  https://www.ebi.ac.uk/ena/portal/api/filereport
# 	Making Request To:  https://www.ebi.ac.uk/ena/portal/api/filereport?accession=PRJNA281708&format=json&download=false&result=read_run
# 	Project Path:  /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/PRJNA281708
#
# 	Run:  SRR1982814
# 	Single Read? : True
# SRR1982814 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA281708/SRR1982814.sam Exists. Continuing.
#
# 	Run:  SRR1982612
# 	Single Read? : True
# SRR1982612 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA281708/SRR1982612.sam Exists. Continuing.
#
#
# 	Run:  SRR1982783
# 	Single Read? : True
# SRR1982783 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA281708/SRR1982783.sam Exists. Continuing.
#
# 	Run:  SRR1982660
# 	Single Read? : True
# SRR1982660 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA281708/SRR1982660.sam Exists. Continuing.
# Processing Project: PRJNA634526
# Accessing:  https://www.ebi.ac.uk/ena/portal/api/filereport
# 	Making Request To:  https://www.ebi.ac.uk/ena/portal/api/filereport?accession=PRJNA634526&format=json&download=false&result=read_run
# 	Project Path:  /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/PRJNA634526
#
# 	Run:  SRR14209603
# 	Single Read? : False
# SRR14209603 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA634526/SRR14209603.sam Exists. Continuing.
#
#
# 	Run:  SRR14209634
# 	Single Read? : False
# SRR14209634 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA634526/SRR14209634.sam Exists. Continuing.
#
# 	Run:  SRR14209655
# 	Single Read? : False
# SRR14209655 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA634526/SRR14209655.sam Exists. Continuing.
#
# 	Run:  SRR14209591
# 	Single Read? : False
# SRR14209591 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA634526/SRR14209591.sam Exists. Continuing.
#
# 	Run:  SRR14209592
# 	Single Read? : False
# SRR14209592 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA634526/SRR14209592.sam Exists. Continuing.
#
# 	Run:  SRR14209589
# 	Single Read? : False
# SRR14209589 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA634526/SRR14209589.sam Exists. Continuing.
#
# 	Run:  SRR14209708
# 	Single Read? : False
# SRR14209708 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA634526/SRR14209708.sam Exists. Continuing.
#
# 	Run:  SRR14209614
# 	Single Read? : False
# SRR14209614 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA634526/SRR14209614.sam Exists. Continuing.
#
# 	Run:  SRR14209590
# 	Single Read? : False
# SRR14209590 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA634526/SRR14209590.sam Exists. Continuing.
#
# 	Run:  SRR14209651
# 	Single Read? : False
# SRR14209651 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA634526/SRR14209651.sam Exists. Continuing.
# Processing Project: PRJEB35615
# Accessing:  https://www.ebi.ac.uk/ena/portal/api/filereport
# 	Making Request To:  https://www.ebi.ac.uk/ena/portal/api/filereport?accession=PRJEB35615&format=json&download=false&result=read_run
# 	Project Path:  /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/PRJEB35615
#
# 	Run:  ERR3698089
# 	Single Read? : False
# ERR3698089 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJEB35615/ERR3698089.sam Exists. Continuing.
#
# 	Run:  ERR3698079
# 	Single Read? : False
# ERR3698079 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJEB35615/ERR3698079.sam Exists. Continuing.
#
# 	Run:  ERR3698058
# 	Single Read? : False
# ERR3698058 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJEB35615/ERR3698058.sam Exists. Continuing.
#
#
# 	Run:  ERR3698061
# 	Single Read? : False
# ERR3698061 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJEB35615/ERR3698061.sam Exists. Continuing.
#
# 	Run:  ERR3698080
# 	Single Read? : False
# ERR3698080 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJEB35615/ERR3698080.sam Exists. Continuing.
#
# 	Run:  ERR3698084
# 	Single Read? : False
# ERR3698084 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJEB35615/ERR3698084.sam Exists. Continuing.
#
# 	Run:  ERR3698055
# 	Single Read? : False
# ERR3698055 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJEB35615/ERR3698055.sam Exists. Continuing.
#
# 	Run:  ERR3698060
# 	Single Read? : False
# ERR3698060 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJEB35615/ERR3698060.sam Exists. Continuing.
#
# 	Run:  ERR3698057
# 	Single Read? : False
# ERR3698057 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJEB35615/ERR3698057.sam Exists. Continuing.
#
# 	Run:  ERR3698053
# 	Single Read? : False
# ERR3698053 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJEB35615/ERR3698053.sam Exists. Continuing.
#
# 	Run:  ERR3698056
# 	Single Read? : False
# ERR3698056 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJEB35615/ERR3698056.sam Exists. Continuing.
# Processing Project: PRJNA277616
# Accessing:  https://www.ebi.ac.uk/ena/portal/api/filereport
# 	Making Request To:  https://www.ebi.ac.uk/ena/portal/api/filereport?accession=PRJNA277616&format=json&download=false&result=read_run
# 	Project Path:  /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/PRJNA277616
#
# 	Run:  SRR1867792
# 	Single Read? : False
# SRR1867792 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA277616/SRR1867792.sam Exists. Continuing.
#
#
# 	Run:  SRR1909639
# 	Single Read? : False
# SRR1909639 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA277616/SRR1909639.sam Exists. Continuing.
#
# 	Run:  SRR1926136
# 	Single Read? : False
# SRR1926136 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA277616/SRR1926136.sam Exists. Continuing.
#
# 	Run:  SRR1926132
# 	Single Read? : False
# SRR1926132 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA277616/SRR1926132.sam Exists. Continuing.
#
# 	Run:  SRR1909613
# 	Single Read? : False
# SRR1909613 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA277616/SRR1909613.sam Exists. Continuing.
#
# 	Run:  SRR1926135
# 	Single Read? : False
# SRR1926135 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA277616/SRR1926135.sam Exists. Continuing.
#
# 	Run:  SRR1926134
# 	Single Read? : False
# SRR1926134 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA277616/SRR1926134.sam Exists. Continuing.
#
# 	Run:  SRR1926133
# 	Single Read? : False
# SRR1926133 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA277616/SRR1926133.sam Exists. Continuing.
#
# 	Run:  SRR1909638
# 	Single Read? : False
# SRR1909638 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA277616/SRR1909638.sam Exists. Continuing.
#
# 	Run:  SRR1909637
# 	Single Read? : False
# SRR1909637 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA277616/SRR1909637.sam Exists. Continuing.
# Processing Project: PRJNA41223
# Accessing:  https://www.ebi.ac.uk/ena/portal/api/filereport
# 	Making Request To:  https://www.ebi.ac.uk/ena/portal/api/filereport?accession=PRJNA41223&format=json&download=false&result=read_run
# 	Project Path:  /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/PRJNA41223
#
# 	Run:  ERR015526
# 	Single Read? : False
# ERR015526 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA41223/ERR015526.sam Exists. Continuing.
#
# 	Run:  ERR013145
# 	Single Read? : False
# ERR013145 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA41223/ERR013145.sam Exists. Continuing.
#
# 	Run:  ERR013144
# 	Single Read? : False
# ERR013144 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA41223/ERR013144.sam Exists. Continuing.
#
# 	Run:  ERR015530
# 	Single Read? : False
# ERR015530 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA41223/ERR015530.sam Exists. Continuing.
#
# 	Run:  ERR015969
# 	Single Read? : False
# ERR015969 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA41223/ERR015969.sam Exists. Continuing.
#
# 	Run:  ERR015879
# 	Single Read? : False
# ERR015879 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA41223/ERR015879.sam Exists. Continuing.
#
# 	Run:  ERR013159
# 	Single Read? : False
# ERR013159 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA41223/ERR013159.sam Exists. Continuing.
#
# 	Run:  ERR016004
# 	Single Read? : False
# ERR016004 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA41223/ERR016004.sam Exists. Continuing.
#
# 	Run:  ERR016160
# 	Single Read? : False
# ERR016160 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA41223/ERR016160.sam Exists. Continuing.
#
# 	Run:  ERR013151
# 	Single Read? : False
# ERR013151 already is processsed. /gpfs/gpfs0/project/ds6011-sp22-wiki-data/ds6011-sp22-dod/data/sam_files/PRJNA41223/ERR013151.sam Exists. Continuing.
